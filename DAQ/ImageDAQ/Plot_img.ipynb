# %%
import h5py as h5
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
fn = '/sf/alvra/config/src/python/photodiag/PhotonDiagControl/DAQ/run02/SATOP11-PSCR0904.h5'

# %%
with h5.File(fn,'r') as fh:
    Img_mean = fh['mean'][:]
    Camera_name = fh['Camera name']
    W = fh['Adjust_W']
    print(list(fh.keys()))
# Out:
# ['AdjustName', 'Adjust_H', 'Adjust_W', 'Adjust_X', 'Adjust_Y', 'Camera name', 'Height', 'Screen position', 'Width', 'images', 'mean']

# %%
plt.figure()
plt.title(Camera_name)
plt.imshow(Img_mean, clim = 10)
# Out:
# <img src="data:image/png;base64,..." width="640">
