# %%
from DAQ_tools import get_image
import matplotlib.pyplot as plt
import numpy as np
import h5py as h5
# %matplotlib notebook
# Out:
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## User inputs

# %%
camName = 'SATFE10-PSCR070'
ROI = [0, 659, 0, 494]
numImg = 10
angle = 0
fN = 'test2.h5'

# %%
! pwd
# Out:
# /gfa/.mounts/sf_alvra/config/src/python/photodiag/PhotonDiagControl/DAQ

# %% [markdown]
# ## Take data

# %%
DataOut = get_image(camName, ROI, numImg,angle)

# %%
print(list(DataOut.keys()))
# Out:
# ['mean', 'image', 'x_profile', 'y_profile', 'x_fwhm', 'y_fwhm', 'x_center_of_mass', 'y_center_of_mass', 'intensity', 'max_value', 'width', 'height']

# %% [markdown]
# ## Save data

# %%
with h5.File(fN,'w-') as fh:
    for k,v in DataOut.items():
        fh[k] = v

# %% [markdown]
# ## Test plots

# %%
DataOut['y_center_of_mass'][:]
# Out:
# []

# %%
plt.figure()
plt.plot(DataOut['y_profile'][1])

# %%
plt.figure()
plt.imshow(DataOut['mean'])
