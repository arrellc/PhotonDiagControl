# %%
import h5py as h5
import matplotlib.pyplot as plt
# Out:
# /sf/alvra/anaconda/4.4.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## User inputs

# %%
fN = 'test2.h5'

# %% [markdown]
# ## Load data

# %%
with h5.File(fN,'r') as fh:
    print(list(fh.keys()))
    IMG = fh['image'][:]
# Out:
# ['height', 'image', 'intensity', 'max_value', 'mean', 'width', 'x_center_of_mass', 'x_fwhm', 'x_profile', 'y_center_of_mass', 'y_fwhm', 'y_profile']

# %%
IMG.shape
# Out:
# (10, 494, 659)

# %%
plt.figure()
plt.imshow(IMG[0,:,:])
